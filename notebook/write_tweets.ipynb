# %%
import pandas as pd

# %%
df = pd.read_pickle('../data/tweets/clean_tweets_24_10_2019.pkl')

# %%
df.head()
# Out:
#                                  source  \
# created_at
# 10-24-2019 03:59:32  Twitter for iPhone
# 10-24-2019 03:54:48  Twitter for iPhone
# 10-24-2019 02:01:35  Twitter for iPhone
# 10-23-2019 21:19:33  Twitter for iPhone
# 10-23-2019 21:12:06  Twitter for iPhone
#
#                                                               raw_text  \
# created_at
# 10-24-2019 03:59:32  RT @bopinion: Of Wisconsin’s 72 counties 23 sw...
# 10-24-2019 03:54:48  RT @realDonaldTrump: https://t.co/ESnxdzR0wM h...
# 10-24-2019 02:01:35    https://t.co/ESnxdzR0wM https://t.co/pcXjrYuQ9e
# 10-23-2019 21:19:33  PROMISES MADE PROMISES KEPT! #SHALEINSIGHT2019...
# 10-23-2019 21:12:06  It was wonderful to be back in Pittsburgh Penn...
#
#                      retweet_count  favorite_count is_retweet  \
# created_at
# 10-24-2019 03:59:32           4802               0       True
# 10-24-2019 03:54:48           6264               0       True
# 10-24-2019 02:01:35           6296           20463      False
# ...

# %%
type(df.index[0])
# Out:
# str

# %%
df.index = pd.to_datetime(df.index)

# %%
type(df.index[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.sort_index(inplace=True)
df.head()
# Out:
#                                  source  \
# created_at
# 2017-01-01 05:00:10  Twitter for iPhone
# 2017-01-01 05:39:13  Twitter for iPhone
# 2017-01-01 05:43:23  Twitter for iPhone
# 2017-01-01 05:44:17  Twitter for iPhone
# 2017-01-01 06:49:33  Twitter for iPhone
#
#                                                               raw_text  \
# created_at
# 2017-01-01 05:00:10  TO ALL AMERICANS-#HappyNewYear &amp; many bles...
# 2017-01-01 05:39:13  RT @DanScavino: On behalf of our next #POTUS &...
# 2017-01-01 05:43:23  RT @Reince: Happy New Year + God's blessings t...
# 2017-01-01 05:44:17  RT @EricTrump: 2016 was such an incredible yea...
# 2017-01-01 06:49:33  RT @DonaldJTrumpJr: Happy new year everyone. #...
#
#                      retweet_count  favorite_count is_retweet  \
# created_at
# 2017-01-01 05:00:10          32665          126230      False
# 2017-01-01 05:39:13           5548               0       True
# 2017-01-01 05:43:23           7144               0       True
# ...

# %%
df.tail()
# Out:
#                                  source  \
# created_at
# 2019-10-23 21:12:06  Twitter for iPhone
# 2019-10-23 21:19:33  Twitter for iPhone
# 2019-10-24 02:01:35  Twitter for iPhone
# 2019-10-24 03:54:48  Twitter for iPhone
# 2019-10-24 03:59:32  Twitter for iPhone
#
#                                                               raw_text  \
# created_at
# 2019-10-23 21:12:06  It was wonderful to be back in Pittsburgh Penn...
# 2019-10-23 21:19:33  PROMISES MADE PROMISES KEPT! #SHALEINSIGHT2019...
# 2019-10-24 02:01:35    https://t.co/ESnxdzR0wM https://t.co/pcXjrYuQ9e
# 2019-10-24 03:54:48  RT @realDonaldTrump: https://t.co/ESnxdzR0wM h...
# 2019-10-24 03:59:32  RT @bopinion: Of Wisconsin’s 72 counties 23 sw...
#
#                      retweet_count  favorite_count is_retweet  \
# created_at
# 2019-10-23 21:12:06          13979           49186      False
# 2019-10-23 21:19:33          16184           61381      False
# 2019-10-24 02:01:35           6296           20463      False
# ...

# %%
file = open('../data/tweets/tweet_text.txt', 'w')

with open('../data/tweets/tweet_text.txt', 'w') as file:
    for tweet in df.clean_text:
        file.write(tweet)
        file.write('\n')
print('done writing')
# Out:
# done writing
